# %%
import pandas as pd
print(pd.__version__)
import sys
print(sys.executable)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 print(pd.__version__)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)import sys
# !{sys.executable} -m pip install pandas
# Out:
# /Users/pit/PitDokumente/ABV Programmieren/ABV_programmieren/.venv/bin/python3

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# /bin/bash: /Users/pit/PitDokumente/ABV: No such file or directory
