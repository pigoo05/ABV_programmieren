# %%
print("hello world")
# Out:
# hello world

# %%
zahl = 10

print(zahl)
# Out:
# 10

# %%
Zahleins = [2,3]

print(Zahleins)
# Out:
# [2, 3]

# %%
yy = 4000
xx = 23
(yy / xx)
# Out:
# 173.91304347826087
